# %% [markdown]
# # This notebook is used to perform bioLUCID on scanpy embedded data

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import scvi
import biolucid

# %% [markdown]
# # Load data

# %%
adata = scvi.data.heart_cell_atlas_subsampled()
# Out:
# INFO     File data/hca_subsampled_20k.h5ad already downloaded

# %%
adata.obs
# Out:
#                                     NRP age_group     cell_source  \
# AACTCCCCACGAGAGT-1-HCAHeart7844001  Yes     65-70     Sanger-CD45
# ATAACGCAGAGCTGGT-1-HCAHeart7829979   No     70-75   Sanger-Nuclei
# GTCAAGTCATGCCACG-1-HCAHeart7702879  Yes     60-65   Sanger-Nuclei
# GGTGATTCAAATGAGT-1-HCAHeart8102858  Yes     60-65     Sanger-CD45
# AGAGAATTCTTAGCAG-1-HCAHeart8102863  Yes     60-65    Sanger-Cells
# ...                                 ...       ...             ...
# CGTCAGGCAAGGCTCC-1-HCAHeart7985087   No     55-60   Sanger-Nuclei
# AGTCACAAGACGAGCT-1-H0035_RV          No     45-50  Harvard-Nuclei
# GGTGAAGGTTCCACAA-1-HCAHeart7844001  Yes     65-70     Sanger-CD45
# CAGCTAAGTACAGACG-1-HCAHeart7702876  Yes     60-65   Sanger-Nuclei
# GATCGTATCAGGTTCA-1-HCAHeart7833852   No     70-75   Sanger-Nuclei
#
#                                                     cell_type donor  gender  \
# AACTCCCCACGAGAGT-1-HCAHeart7844001                    Myeloid    D6    Male
# ATAACGCAGAGCTGGT-1-HCAHeart7829979  Ventricular_Cardiomyocyte    D4  Female
# GTCAAGTCATGCCACG-1-HCAHeart7702879                 Fibroblast    D2    Male
# GGTGATTCAAATGAGT-1-HCAHeart8102858                Endothelial   D11  Female
# AGAGAATTCTTAGCAG-1-HCAHeart8102863                Endothelial   D11  Female
# ...                                                       ...   ...     ...
# CGTCAGGCAAGGCTCC-1-HCAHeart7985087  Ventricular_Cardiomyocyte    D3    Male
# AGTCACAAGACGAGCT-1-H0035_RV                         Pericytes    H7  Female
# GGTGAAGGTTCCACAA-1-HCAHeart7844001                   Lymphoid    D6    Male
# CAGCTAAGTACAGACG-1-HCAHeart7702876       Atrial_Cardiomyocyte    D2    Male
# GATCGTATCAGGTTCA-1-HCAHeart7833852       Atrial_Cardiomyocyte    D4  Female
#
#                                     n_counts  n_genes  percent_mito  \
# AACTCCCCACGAGAGT-1-HCAHeart7844001    1420.0      738      0.054930
# ATAACGCAGAGCTGGT-1-HCAHeart7829979     844.0      505      0.001185
# GTCAAGTCATGCCACG-1-HCAHeart7702879    1491.0      862      0.000000
# GGTGATTCAAATGAGT-1-HCAHeart8102858    2167.0     1115      0.064144
# AGAGAATTCTTAGCAG-1-HCAHeart8102863    7334.0     2505      0.093537
# ...                                      ...      ...           ...
# CGTCAGGCAAGGCTCC-1-HCAHeart7985087    4478.0     2243      0.002233
# AGTCACAAGACGAGCT-1-H0035_RV            967.0      630      0.002068
# GGTGAAGGTTCCACAA-1-HCAHeart7844001    1599.0      619      0.041901
# CAGCTAAGTACAGACG-1-HCAHeart7702876    3715.0     1523      0.000269
# GATCGTATCAGGTTCA-1-HCAHeart7833852    2246.0      945      0.000445
#
#                                     percent_ribo region           sample  \
# AACTCCCCACGAGAGT-1-HCAHeart7844001      0.064789     LA  HCAHeart7844001
# ATAACGCAGAGCTGGT-1-HCAHeart7829979      0.001185     RV  HCAHeart7829979
# GTCAAGTCATGCCACG-1-HCAHeart7702879      0.005366     RA  HCAHeart7702879
# GGTGATTCAAATGAGT-1-HCAHeart8102858      0.027227     LA  HCAHeart8102858
# AGAGAATTCTTAGCAG-1-HCAHeart8102863      0.040496     RA  HCAHeart8102863
# ...                                          ...    ...              ...
# CGTCAGGCAAGGCTCC-1-HCAHeart7985087      0.001340     RV  HCAHeart7985087
# AGTCACAAGACGAGCT-1-H0035_RV             0.004137     RV         H0035_RV
# GGTGAAGGTTCCACAA-1-HCAHeart7844001      0.155722     LA  HCAHeart7844001
# CAGCTAAGTACAGACG-1-HCAHeart7702876      0.002423     LA  HCAHeart7702876
# GATCGTATCAGGTTCA-1-HCAHeart7833852      0.000890     LA  HCAHeart7833852
#
#                                     scrublet_score  source type version  \
# AACTCCCCACGAGAGT-1-HCAHeart7844001        0.113475   CD45+  DCD      V2
# ATAACGCAGAGCTGGT-1-HCAHeart7829979        0.085546  Nuclei  DCD      V2
# GTCAAGTCATGCCACG-1-HCAHeart7702879        0.197861  Nuclei  DCD      V2
# GGTGATTCAAATGAGT-1-HCAHeart8102858        0.113475   CD45+  DCD      V3
# AGAGAATTCTTAGCAG-1-HCAHeart8102863        0.132150   Cells  DCD      V3
# ...                                            ...     ...  ...     ...
# CGTCAGGCAAGGCTCC-1-HCAHeart7985087        0.185751  Nuclei  DBD      V2
# AGTCACAAGACGAGCT-1-H0035_RV               0.081779  Nuclei  DBD      V3
# GGTGAAGGTTCCACAA-1-HCAHeart7844001        0.074830   CD45+  DCD      V2
# CAGCTAAGTACAGACG-1-HCAHeart7702876        0.048649  Nuclei  DCD      V2
# GATCGTATCAGGTTCA-1-HCAHeart7833852        0.132150  Nuclei  DCD      V2
#
#                                       cell_states Used
# AACTCCCCACGAGAGT-1-HCAHeart7844001      LYVE1+MØ1  Yes
# ATAACGCAGAGCTGGT-1-HCAHeart7829979           vCM1  Yes
# GTCAAGTCATGCCACG-1-HCAHeart7702879            FB2  Yes
# GGTGATTCAAATGAGT-1-HCAHeart8102858  EC10_CMC-like  Yes
# AGAGAATTCTTAGCAG-1-HCAHeart8102863        EC5_art  Yes
# ...                                           ...  ...
# CGTCAGGCAAGGCTCC-1-HCAHeart7985087           vCM1  Yes
# AGTCACAAGACGAGCT-1-H0035_RV              PC1_vent  Yes
# GGTGAAGGTTCCACAA-1-HCAHeart7844001      CD4+T_tem  Yes
# CAGCTAAGTACAGACG-1-HCAHeart7702876           aCM3  Yes
# GATCGTATCAGGTTCA-1-HCAHeart7833852           aCM3  Yes
#
# [18641 rows x 18 columns]

# %%
print(f"Number of cells: {adata.n_obs}")
print(f"Number of genes: {adata.n_vars}")
print("Unique batches:")
print(adata.obs['donor'].unique())
print("\nUnique cell types:")
print(adata.obs['cell_type'].unique())
# Out:
# Number of cells: 18641
# Number of genes: 26662
# Unique batches:
# ['D6', 'D4', 'D2', 'D11', 'H4', ..., 'D1', 'D7', 'H6', 'H7', 'H3']
# Length: 14
# Categories (14, object): ['D1', 'D2', 'D3', 'D4', ..., 'H4', 'H5', 'H6', 'H7']
#
# Unique cell types:
# ['Myeloid', 'Ventricular_Cardiomyocyte', 'Fibroblast', 'Endothelial', 'Adipocytes', ..., 'Atrial_Cardiomyocyte', 'Smooth_muscle_cells', 'Neuronal', 'Lymphoid', 'Mesothelial']
# Length: 11
# Categories (11, object): ['Adipocytes', 'Atrial_Cardiomyocyte', 'Endothelial', 'Fibroblast', ..., 'Neuronal', 'Pericytes', 'Smooth_muscle_cells', 'Ventricular_Cardiomyocyte']

# %%
print("Batch-celltype distribution:")
print(pd.crosstab(adata.obs['donor'], adata.obs['cell_type']))
# Out:
# Batch-celltype distribution:
# cell_type  Adipocytes  Atrial_Cardiomyocyte  Endothelial  Fibroblast  \
# donor
# D1                  0                    10           38         101
# D2                 19                   100          136         570
# D3                  5                   127          151         202
# D4                 11                    92          114         310
# D5                  3                   109          179         237
# D6                  6                    98         1673         116
# D7                  8                   129          365         143
# D11                 8                    10          896         153
# H2                 11                    11          127          99
# H3                 19                    63          104         125
# H4                  7                    25           70          69
# H5                 20                    27          127         113
# H6                 15                    53           69         105
# H7                 13                   155           60         103
#
# cell_type  Lymphoid  Mesothelial  Myeloid  Neuronal  Pericytes  \
# donor
# D1               10            0       12         4         77
# D2               27            1       53         9        241
# D3               12            1       66         6        175
# D4                9            1       53        13        192
# D5                6            2       40         7        177
# D6              182            9      187        24        372
# D7              156            3      147         6        134
# D11              81            0      145         7        297
# H2               55            0       53        13        207
# H3               28            0       55        11        298
# H4               20            0       25        14        317
# H5               21            0       40        14        272
# H6               20            0       29        13        152
# H7               26            0       52        12        293
#
# cell_type  Smooth_muscle_cells  Ventricular_Cardiomyocyte
# donor
# D1                           3                        326
# D2                          19                        539
# D3                          42                        212
# D4                          28                        321
# D5                          30                        371
# D6                         127                        215
# D7                          43                        252
# D11                         55                        199
# H2                          33                        228
# H3                          59                        418
# H4                          59                        440
# H5                          66                        814
# H6                          32                        539
# H7                          45                        433

# %% [markdown]
# # Run bioLUCID

# %%
analyzer = biolucid.core.BatchEffectAnalyzer(
    adata,
    params={
        'batch_key': 'donor',         
        'celltype_key': 'cell_type',
    }
)
# Out:
# 2026-05-27 13:58:18,913 - INFO - Initialized analyzer with valid parameters
# 2026-05-27 13:58:18,913 - INFO - === Analysis Parameters ===
# 2026-05-27 13:58:18,914 - INFO - batch_key: donor
# 2026-05-27 13:58:18,914 - INFO - celltype_key: cell_type
# 2026-05-27 13:58:18,914 - INFO - min_cells: 20
# 2026-05-27 13:58:18,914 - INFO - abundant_gene_threshold: 1
# 2026-05-27 13:58:18,915 - INFO - min_abundant_genes: 100

# %%
# it costs 3 minutes to run the analysis
analyzer.run_analysis()
# Out:
# 2026-05-27 13:58:55,715 - INFO - Starting analysis pipeline
# 2026-05-27 13:58:55,715 - INFO - Preprocessing data
# 2026-05-27 13:58:55,715 - INFO - Starting data preprocessing
# 2026-05-27 13:58:56,073 - INFO - Optimization finished: Selected 4 cell types and 14 samples (Score: 0.8750)
# 2026-05-27 13:58:56,073 - INFO - Retained 15066 / 18641 cells after filtering
# 2026-05-27 13:58:56,073 - INFO - Retained cell types: ['Ventricular_Cardiomyocyte', 'Endothelial', 'Pericytes', 'Fibroblast']
# 2026-05-27 13:58:56,074 - INFO - Retained samples: ['D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D11', 'H2', 'H3', 'H4', 'H5', 'H6', 'H7']
# 2026-05-27 13:58:56,074 - INFO - Cell counts per batch for retained cell types:
# 2026-05-27 13:58:56,075 - INFO - Batch D1:
# 2026-05-27 13:58:56,075 - INFO -   Ventricular_Cardiomyocyte: 326 cells
# 2026-05-27 13:58:56,075 - INFO -   Endothelial: 38 cells
# 2026-05-27 13:58:56,076 - INFO -   Pericytes: 77 cells
# 2026-05-27 13:58:56,076 - INFO -   Fibroblast: 101 cells
# 2026-05-27 13:58:56,076 - INFO - Batch D2:
# 2026-05-27 13:58:56,077 - INFO -   Ventricular_Cardiomyocyte: 539 cells
# 2026-05-27 13:58:56,077 - INFO -   Endothelial: 136 cells
# 2026-05-27 13:58:56,077 - INFO -   Pericytes: 241 cells
# 2026-05-27 13:58:56,077 - INFO -   Fibroblast: 570 cells
# 2026-05-27 13:58:56,077 - INFO - Batch D3:
# 2026-05-27 13:58:56,078 - INFO -   Ventricular_Cardiomyocyte: 212 cells
# 2026-05-27 13:58:56,078 - INFO -   Endothelial: 151 cells
# 2026-05-27 13:58:56,078 - INFO -   Pericytes: 175 cells
# 2026-05-27 13:58:56,078 - INFO -   Fibroblast: 202 cells
# 2026-05-27 13:58:56,079 - INFO - Batch D4:
# 2026-05-27 13:58:56,079 - INFO -   Ventricular_Cardiomyocyte: 321 cells
# 2026-05-27 13:58:56,079 - INFO -   Endothelial: 114 cells
# 2026-05-27 13:58:56,079 - INFO -   Pericytes: 192 cells
# 2026-05-27 13:58:56,080 - INFO -   Fibroblast: 310 cells
# 2026-05-27 13:58:56,080 - INFO - Batch D5:
# 2026-05-27 13:58:56,080 - INFO -   Ventricular_Cardiomyocyte: 371 cells
# 2026-05-27 13:58:56,080 - INFO -   Endothelial: 179 cells
# 2026-05-27 13:58:56,080 - INFO -   Pericytes: 177 cells
# 2026-05-27 13:58:56,080 - INFO -   Fibroblast: 237 cells
# 2026-05-27 13:58:56,081 - INFO - Batch D6:
# 2026-05-27 13:58:56,081 - INFO -   Ventricular_Cardiomyocyte: 215 cells
# 2026-05-27 13:58:56,081 - INFO -   Endothelial: 1673 cells
# 2026-05-27 13:58:56,081 - INFO -   Pericytes: 372 cells
# 2026-05-27 13:58:56,081 - INFO -   Fibroblast: 116 cells
# 2026-05-27 13:58:56,082 - INFO - Batch D7:
# 2026-05-27 13:58:56,082 - INFO -   Ventricular_Cardiomyocyte: 252 cells
# 2026-05-27 13:58:56,082 - INFO -   Endothelial: 365 cells
# 2026-05-27 13:58:56,082 - INFO -   Pericytes: 134 cells
# 2026-05-27 13:58:56,085 - INFO -   Fibroblast: 143 cells
# 2026-05-27 13:58:56,089 - INFO - Batch D11:
# 2026-05-27 13:58:56,089 - INFO -   Ventricular_Cardiomyocyte: 199 cells
# 2026-05-27 13:58:56,090 - INFO -   Endothelial: 896 cells
# 2026-05-27 13:58:56,095 - INFO -   Pericytes: 297 cells
# 2026-05-27 13:58:56,100 - INFO -   Fibroblast: 153 cells
# 2026-05-27 13:58:56,101 - INFO - Batch H2:
# 2026-05-27 13:58:56,101 - INFO -   Ventricular_Cardiomyocyte: 228 cells
# 2026-05-27 13:58:56,102 - INFO -   Endothelial: 127 cells
# 2026-05-27 13:58:56,103 - INFO -   Pericytes: 207 cells
# 2026-05-27 13:58:56,103 - INFO -   Fibroblast: 99 cells
# 2026-05-27 13:58:56,104 - INFO - Batch H3:
# 2026-05-27 13:58:56,104 - INFO -   Ventricular_Cardiomyocyte: 418 cells
# 2026-05-27 13:58:56,104 - INFO -   Endothelial: 104 cells
# 2026-05-27 13:58:56,104 - INFO -   Pericytes: 298 cells
# 2026-05-27 13:58:56,104 - INFO -   Fibroblast: 125 cells
# 2026-05-27 13:58:56,104 - INFO - Batch H4:
# 2026-05-27 13:58:56,105 - INFO -   Ventricular_Cardiomyocyte: 440 cells
# 2026-05-27 13:58:56,105 - INFO -   Endothelial: 70 cells
# 2026-05-27 13:58:56,105 - INFO -   Pericytes: 317 cells
# 2026-05-27 13:58:56,105 - INFO -   Fibroblast: 69 cells
# 2026-05-27 13:58:56,105 - INFO - Batch H5:
# 2026-05-27 13:58:56,105 - INFO -   Ventricular_Cardiomyocyte: 814 cells
# 2026-05-27 13:58:56,106 - INFO -   Endothelial: 127 cells
# 2026-05-27 13:58:56,106 - INFO -   Pericytes: 272 cells
# 2026-05-27 13:58:56,106 - INFO -   Fibroblast: 113 cells
# 2026-05-27 13:58:56,106 - INFO - Batch H6:
# 2026-05-27 13:58:56,106 - INFO -   Ventricular_Cardiomyocyte: 539 cells
# 2026-05-27 13:58:56,106 - INFO -   Endothelial: 69 cells
# 2026-05-27 13:58:56,106 - INFO -   Pericytes: 152 cells
# 2026-05-27 13:58:56,106 - INFO -   Fibroblast: 105 cells
# 2026-05-27 13:58:56,107 - INFO - Batch H7:
# 2026-05-27 13:58:56,107 - INFO -   Ventricular_Cardiomyocyte: 433 cells
# 2026-05-27 13:58:56,107 - INFO -   Endothelial: 60 cells
# 2026-05-27 13:58:56,107 - INFO -   Pericytes: 293 cells
# 2026-05-27 13:58:56,107 - INFO -   Fibroblast: 103 cells
# 2026-05-27 13:58:56,214 - INFO - Found counts in X
# 2026-05-27 13:58:56,640 - INFO - Selected 288 abundant genes
# 2026-05-27 13:58:56,673 - INFO - Found counts in X
# 2026-05-27 13:58:56,675 - INFO - Storing raw counts in 'layers["counts"]'
# 2026-05-27 13:58:56,696 - INFO - Data preprocessing completed
# 2026-05-27 13:58:56,696 - INFO - === Batch Effect Analysis Data ===
# 2026-05-27 13:58:56,696 - INFO - Raw data: AnnData object with n_obs × n_vars = 18641 × 26662
#     obs: 'NRP', 'age_group', 'cell_source', 'cell_type', 'donor', 'gender', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'region', 'sample', 'scrublet_score', 'source', 'type', 'version', 'cell_states', 'Used'
#     var: 'gene_ids-Harvard-Nuclei', 'feature_types-Harvard-Nuclei', 'gene_ids-Sanger-Nuclei', 'feature_types-Sanger-Nuclei', 'gene_ids-Sanger-Cells', 'feature_types-Sanger-Cells', 'gene_ids-Sanger-CD45', 'feature_types-Sanger-CD45', 'n_counts'
#     uns: 'cell_type_colors'
# 2026-05-27 13:58:56,696 - INFO - Processed data: AnnData object with n_obs × n_vars = 15066 × 288
#     obs: 'NRP', 'age_group', 'cell_source', 'cell_type', 'donor', 'gender', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'region', 'sample', 'scrublet_score', 'source', 'type', 'version', 'cell_states', 'Used'
#     var: 'gene_ids-Harvard-Nuclei', 'feature_types-Harvard-Nuclei', 'gene_ids-Sanger-Nuclei', 'feature_types-Sanger-Nuclei', 'gene_ids-Sanger-Cells', 'feature_types-Sanger-Cells', 'gene_ids-Sanger-CD45', 'feature_types-Sanger-CD45', 'n_counts'
#     uns: 'cell_type_colors', 'biolucid_dropped_samples'
#     layers: 'counts', 'logTPM'
# /Users/yusong/Desktop/JEAN_LAB/biolucid/biolucid/src/biolucid/core/calculator.py:29: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   X_st = data.groupby(['sample_id', 'cluster_id', 'gene_id'])['expression_value'].mean()
# /Users/yusong/Desktop/JEAN_LAB/biolucid/biolucid/src/biolucid/core/calculator.py:76: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(['cluster_id', 'gene_id'])
# /Users/yusong/Desktop/JEAN_LAB/biolucid/biolucid/src/biolucid/core/calculator.py:77: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: (x['expression_value_st'] - x['expression_value_mean']).mean()))
# /Users/yusong/Desktop/JEAN_LAB/biolucid/biolucid/src/biolucid/core/calculator.py:106: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(['sample_id', 'gene_id'])
# /Users/yusong/Desktop/JEAN_LAB/biolucid/biolucid/src/biolucid/core/calculator.py:107: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: (x['expression_value_st'] -
# /Users/yusong/Desktop/JEAN_LAB/biolucid/biolucid/src/biolucid/core/calculator.py:174: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for sample, group in sigma_s_df.groupby('sample_id')
# /Users/yusong/Desktop/JEAN_LAB/biolucid/biolucid/src/biolucid/core/calculator.py:193: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for sample, group in residuals_df.groupby('sample_id')
# 2026-05-27 13:58:57,075 - INFO - Analysis pipeline completed
# bioLUCIDResult(Global_b_score=0.6179264187812805, Global_q_sh_score=0.19779789447784424, Global_q_sp_score=0.15499266982078552, b_score_per_batch={'D1': np.float32(0.5844757), 'D2': np.float32(0.56991696), 'D3': np.float32(0.54296905), 'D4': np.float32(0.6690537), 'D5': np.float32(0.6228658), 'D6': np.float32(0.71411324), 'D7': np.float32(0.5712998), 'D11': np.float32(0.5007987), 'H2': np.float32(0.63303196), 'H3': np.float32(0.6852044), 'H4': np.float32(0.59561807), 'H5': np.float32(0.66752005), 'H6': np.float32(0.6402771), 'H7': np.float32(0.65382445)}, q_sh_score_per_batch={'D1': np.float32(0.14584973), 'D2': np.float32(0.11698849), 'D3': np.float32(0.13796264), 'D4': np.float32(0.13729821), 'D5': np.float32(0.17687157), 'D6': np.float32(0.395098), 'D7': np.float32(0.21888804), 'D11': np.float32(0.3095035), 'H2': np.float32(0.18720458), 'H3': np.float32(0.19906995), 'H4': np.float32(0.17541136), 'H5': np.float32(0.19027656), 'H6': np.float32(0.18435106), 'H7': np.float32(0.19439676)}, q_sp_score_per_batch={'D1': np.float32(0.122976065), 'D2': np.float32(0.10162803), 'D3': np.float32(0.12657465), 'D4': np.float32(0.09656354), 'D5': np.float32(0.1376286), 'D6': np.float32(0.24998753), 'D7': np.float32(0.18961246), 'D11': np.float32(0.3090095), 'H2': np.float32(0.14253378), 'H3': np.float32(0.13493046), 'H4': np.float32(0.14453387), 'H5': np.float32(0.13428758), 'H6': np.float32(0.13818015), 'H7': np.float32(0.1414512)}, components={'μ': gene_id
# A2M           0.377619
# ABLIM1        0.697479
# AC011287.1    0.239064
# AC016831.7    0.642493
# ACTB          0.596241
#                 ...
# ZBTB16        0.576194
# ZBTB20        1.111922
# ZFP36         0.251859
# ZFPM2         0.550358
# ZNF638        0.453285
# Name: expression_value, Length: 288, dtype: float32, 'X_st': sample_id  cluster_id                 gene_id
# D1         Endothelial                A2M           0.545980
#                                       ABLIM1        0.499673
#                                       AC011287.1    0.087977
#                                       AC016831.7    0.428302
#                                       ACTB          1.080533
#                                                       ...
# H7         Ventricular_Cardiomyocyte  ZBTB16        0.780031
#                                       ZBTB20        1.157975
#                                       ZFP36         0.014166
#                                       ZFPM2         0.711366
#                                       ZNF638        0.596978
# Name: expression_value, Length: 16128, dtype: float32, 'tau_t': cluster_id                 gene_id
# Endothelial                A2M           0.486826
#                            ABLIM1        0.208934
#                            AC011287.1   -0.143573
#                            AC016831.7   -0.068224
#                            ACTB          0.221027
#                                            ...
# Ventricular_Cardiomyocyte  ZBTB16       -0.088739
#                            ZBTB20       -0.156840
#                            ZFP36        -0.202270
#                            ZFPM2         0.112554
#                            ZNF638        0.065322
# Length: 1152, dtype: float32, 'sigma_s': sample_id  gene_id
# D1         A2M          -0.150292
#            ABLIM1       -0.236583
#            AC011287.1   -0.103723
#            AC016831.7   -0.149555
#            ACTB         -0.040638
#                            ...
# H7         ZBTB16        0.571795
#            ZBTB20        0.425199
#            ZFP36        -0.139895
#            ZFPM2         0.103462
#            ZNF638        0.182162
# Length: 4032, dtype: float32, 'residuals':       sample_id                 cluster_id     gene_id  residuals
# 0            D1                Endothelial         A2M  -0.168173
# 1            D1                Endothelial      ABLIM1  -0.170157
# 2            D1                Endothelial  AC011287.1   0.096209
# 3            D1                Endothelial  AC016831.7   0.003588
# 4            D1                Endothelial        ACTB   0.303903
# ...         ...                        ...         ...        ...
# 16123        H7  Ventricular_Cardiomyocyte      ZBTB16  -0.279219
# 16124        H7  Ventricular_Cardiomyocyte      ZBTB20  -0.222306
# 16125        H7  Ventricular_Cardiomyocyte       ZFP36   0.104471
# 16126        H7  Ventricular_Cardiomyocyte       ZFPM2  -0.055008
# 16127        H7  Ventricular_Cardiomyocyte      ZNF638  -0.103791
#
# [16128 rows x 4 columns]})

# %% [markdown]
# # Get results

# %%
results = analyzer.results

# %%
# import pickle
# with open('output_file.pkl','wb') as f:
#     pickle.dump(results, f)

# %% [markdown]
# # Vis

# %%
global_results_df,per_sample_results_df = biolucid.visualization.results_to_df(results)

# %%
global_results_df
# Out:
#    Global_b_score  Global_q_sp_score  Global_q_sh_score
# 0        0.617926           0.154993           0.197798

# %%
per_sample_results_df
# Out:
#      q_sh_score_per_batch  q_sp_score_per_batch  b_score_per_batch  \
# D1               0.145850              0.122976           0.584476
# D2               0.116988              0.101628           0.569917
# D3               0.137963              0.126575           0.542969
# D4               0.137298              0.096564           0.669054
# D5               0.176872              0.137629           0.622866
# D6               0.395098              0.249988           0.714113
# D7               0.218888              0.189612           0.571300
# D11              0.309503              0.309009           0.500799
# H2               0.187205              0.142534           0.633032
# H3               0.199070              0.134930           0.685204
# H4               0.175411              0.144534           0.595618
# H5               0.190277              0.134288           0.667520
# H6               0.184351              0.138180           0.640277
# H7               0.194397              0.141451           0.653824
#
#         recommendation
# D1                Keep
# D2                Keep
# D3                Keep
# D4   Keep with caution
# D5   Keep with caution
# D6   Keep with caution
# D7                Keep
# D11               Keep
# H2   Keep with caution
# H3   Keep with caution
# H4                Keep
# H5   Keep with caution
# H6   Keep with caution
# H7   Keep with caution

# %% [markdown]
# ## Barplot

# %%
biolucid.visualization.plot_scatter_analysis(per_sample_results_df)
